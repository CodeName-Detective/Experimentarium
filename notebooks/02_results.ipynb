# %% [markdown]
# # Results Analysis

# %%
import sys

sys.path.insert(0, '..')
import wandb

api = wandb.Api()
runs = api.runs('your-entity/your-project')

# %%
# TODO: pull metrics and plot training curves
